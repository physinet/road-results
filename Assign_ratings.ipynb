# %%
import dill
import re
import glob

import pandas as pd
import trueskill as ts
import numpy as np

ts.setup(backend='mpmath')

from preprocess import clean

# %%
df_meta = pd.read_pickle('C:/data/results/df.pkl')
df_meta.sample(5)
# Out:
#                                                       name  \
# race_id
# 1089     Northern California/Nevada Time Trial Champion...
# 3176                            Tour of Galena - Criterium
# 3150                                   Tour of Galena - TT
# 4240                               The Bunny Hop Criterium
# 4397          Killington Stage Race Circuit Race - Stage 1
#
#                         date             loc  \
# race_id
# 1089     2011-06-12 00:00:00
# 3176     2012-06-09 00:00:00      Galena, IL
# 3150     2013-06-08 00:00:00      Galena, IL
# 4240     2014-05-04 00:00:00    Suitland, MD
# 4397     2014-05-24 00:00:00  Killington, VT
#
#                                     json_url  \
# race_id
# 1089     downloadrace.php?raceID=1089&json=1
# 3176     downloadrace.php?raceID=3176&json=1
# 3150     downloadrace.php?raceID=3150&json=1
# 4240     downloadrace.php?raceID=4240&json=1
# 4397     downloadrace.php?raceID=4397&json=1
#
#                                                  weather  \
# race_id
# 1089
# 3176                     Clear, 82  degrees, wind 14 mph
# 3150              Partly Cloudy, 69  degrees, wind 6 mph
# 4240             Partly Cloudy, 71  degrees, wind 13 mph
# 4397              Partly Cloudy, 60  degrees, wind 2 mph
#
#                               strava_url coord
# race_id
# 1089     http://app.strava.com/segments/  None
# 3176     http://app.strava.com/segments/  None
# 3150     http://app.strava.com/segments/  None
# 4240     http://app.strava.com/segments/  None
# 4397     http://app.strava.com/segments/  None

# %%
json = dill.load(open('C:\\data\\results\\races\\1000.pkd', 'rb'))

df_race = pd.read_json(json)
df_race = clean(df_race).assign(race_id=1000, rating_prev=ts.Rating(), rating=ts.Rating())

df_all_races = pd.DataFrame(columns = df_race.columns)

# %%
df_all_races
# Out:
# Empty DataFrame
# Columns: [Place, RaceTime, Name, Age, Category, RacerID, TeamID, TeamName, RaceName, RaceCategoryName, IsDQ, race_id, rating_prev, rating]
# Index: []

# %%
# Dataframe to store most recent info for each racer
df_racers = pd.DataFrame(columns=['Name', 'Age', 'Category', 'RacerID', 'TeamID', 'TeamName', 'rating'])
df_racers = df_racers.set_index('RacerID')

# %%
def get_prev_rating(row):
    racer_id = row['RacerID']
    if racer_id not in df_racers.index: # Racer we haven't seen before
        df_racers.loc[racer_id] = row
        df_racers.loc[racer_id, 'rating'] = [ts.Rating()]
        
    row['rating_prev'] = df_racers.loc[racer_id, 'rating']
    return row
            
    
def get_ratings(df):
    df = df[~df['Place'].isna()]
    placing = df['Place']
    if not (placing.sort_values().values == placing.values).all():
        raise Exception('Placing not in order!')
        
    new_ratings = ts.rate([(df_racers.loc[racer_id, 'rating'],) for racer_id in df['RacerID']])
    df = df.assign(rating=[r[0] for r in new_ratings])
    return df

    
for j, (index, row) in enumerate(df_meta.iterrows()):
    json = dill.load(open(f'C:\\data\\results\\races\\{index}.pkd', 'rb'))

    df_race = pd.read_json(json)
    if df_race.empty:
        continue
        
    # "previous rating" column - initialize with default rating and update if already rated
    df_race = clean(df_race).assign(race_id=int(index), rating_prev=ts.Rating(), rating=ts.Rating())
    df_race = df_race.apply(get_prev_rating, axis=1)
    
    # Group by race category and get new ratings
    g = df_race.groupby('RaceCategoryName')
    for name, group in g:
        new_ratings = get_ratings(group)
        df_race.update(new_ratings)
        df_racers.update(new_ratings)
    
    df_all_races = pd.concat([df_all_races, df_race])
        
    if j == 10:
        break

# %%
df_racers.sample(5)
# Out:
#                     Name   Age  Category  TeamID        TeamName  \
# RacerID
# 878      Jonathan Bielik   NaN       NaN  1305.0        Benidorm
# 1246      Andrew Randell   NaN       NaN  1436.0      Symmetrics
# 1238     Michelle Bishop  29.0       3.0     NaN             NaN
# 1598       Leo Deveilian   NaN       NaN   975.0          CCB/VW
# 1656      Rami El rayess  30.0       4.0  1601.0  Slouch/NorEast
#
#                                            rating
# RacerID
# 878      trueskill.Rating(mu=25.000, sigma=8.333)
# 1246     trueskill.Rating(mu=25.000, sigma=8.333)
# 1238     trueskill.Rating(mu=25.000, sigma=8.333)
# 1598     trueskill.Rating(mu=25.000, sigma=8.333)
# 1656     trueskill.Rating(mu=25.000, sigma=8.333)

# %%
df_all_races.head()
# Out:
#    Place RaceTime              Name   Age  Category RacerID   TeamID  \
# 0    1.0  2:28:53      Matt Cuttler  29.0       3.0     699  12737.0
# 1    2.0       st     Eric Weinrich  42.0       3.0     700   1249.0
# 2    3.0       st  Michael Boardman  34.0       3.0     701      NaN
# 3    4.0       st       John Nobile  45.0       4.0     702      NaN
# 4    5.0       st        Ryan Short  20.0       4.0     703   1222.0
#
#                     TeamName                        RaceName  \
# 0       CRCA/Affinity Cycles  NCC 10th Tour of the Hilltowns
# 1  portland velo-cycle-mania  NCC 10th Tour of the Hilltowns
# 2                        NaN  NCC 10th Tour of the Hilltowns
# 3                        NaN  NCC 10th Tour of the Hilltowns
# 4         TEAM PLACID PLANET  NCC 10th Tour of the Hilltowns
#
#         RaceCategoryName   IsDQ race_id  \
# 0  Cat 4                  False       2
# 1  Cat 4                  False       2
# 2  Cat 4                  False       2
# 3  Cat 4                  False       2
# 4  Cat 4                  False       2
#
#                                 rating_prev  \
# 0  trueskill.Rating(mu=25.000, sigma=8.333)
# 1  trueskill.Rating(mu=25.000, sigma=8.333)
# 2  trueskill.Rating(mu=25.000, sigma=8.333)
# 3  trueskill.Rating(mu=25.000, sigma=8.333)
# 4  trueskill.Rating(mu=25.000, sigma=8.333)
#
#                                      rating
# 0  trueskill.Rating(mu=25.000, sigma=8.333)
# 1  trueskill.Rating(mu=25.000, sigma=8.333)
# 2  trueskill.Rating(mu=25.000, sigma=8.333)
# 3  trueskill.Rating(mu=25.000, sigma=8.333)
# 4  trueskill.Rating(mu=25.000, sigma=8.333)
