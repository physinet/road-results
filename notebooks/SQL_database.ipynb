# %%
import dill
import re
import glob

import pandas as pd
import trueskill as ts
import numpy as np
import matplotlib.pyplot as plt

ts.setup(backend='mpmath')
RATING = {'mu': ts.MU, 'sigma': ts.SIGMA}  # initial rating

from preprocess import clean

# %%
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, DateTime, Float


engine = sqlalchemy.create_engine('sqlite:///data/races.sqlite')
session = sqlalchemy.orm.sessionmaker(bind=engine)()

# %% [markdown]
# # Race metadata (already collected into a dataframe)

# %%
df_meta = pd.read_pickle('C:/data/results/df.pkl')
df_meta.head(5)
# Out:
#                                                       name  \
# race_id
# 2                           NCC 10th Tour of the Hilltowns
# 3                   Bethel Spring Series - Ronde de Bethel
# 4        4th Annual Smuttynose Brewing Co. Portsmouth C...
# 5                                   Topsfield Circuit Race
# 6                                Green Mountain Stage Crit
#
#                         date loc                          json_url weather  \
# race_id
# 2        2008-07-26 00:00:00      downloadrace.php?raceID=2&json=1
# 3        2008-03-02 00:00:00      downloadrace.php?raceID=3&json=1
# 4        2008-09-21 00:00:00      downloadrace.php?raceID=4&json=1
# 5        2008-09-06 00:00:00      downloadrace.php?raceID=5&json=1
# 6        2008-09-01 00:00:00      downloadrace.php?raceID=6&json=1
#
#                               strava_url coord
# race_id
# 2        http://app.strava.com/segments/  None
# 3        http://app.strava.com/segments/  None
# 4        http://app.strava.com/segments/  None
# 5        http://app.strava.com/segments/  None
# 6        http://app.strava.com/segments/  None

# %%
df_meta[['name', 'date', 'loc', 'json_url', 'weather']].to_sql('metadata', engine, if_exists='replace')

# %%
Base = declarative_base()

class Metadata(Base):
    __tablename__ = "metadata"
    
    # sqlalchemy uses these names as the column names
    race_id = Column(Integer, primary_key=True)
    name = Column(String)
    date = Column(DateTime)
    loc = Column(String)
    json_url = Column(String)
    weather = Column(String)

# %%
results = session.query(Metadata.race_id, Metadata.name, Metadata.date, Metadata.loc, Metadata.json_url, Metadata.weather)
for row in results[:10]:
    print(row)
# Out:
# (2, 'NCC 10th Tour of the Hilltowns', datetime.datetime(2008, 7, 26, 0, 0), '', 'downloadrace.php?raceID=2&json=1', '')
# (3, 'Bethel Spring Series - Ronde de Bethel', datetime.datetime(2008, 3, 2, 0, 0), '', 'downloadrace.php?raceID=3&json=1', '')
# (4, '4th Annual Smuttynose Brewing Co. Portsmouth Criterium', datetime.datetime(2008, 9, 21, 0, 0), '', 'downloadrace.php?raceID=4&json=1', '')
# (5, 'Topsfield Circuit Race', datetime.datetime(2008, 9, 6, 0, 0), '', 'downloadrace.php?raceID=5&json=1', '')
# (6, 'Green Mountain Stage Crit', datetime.datetime(2008, 9, 1, 0, 0), '', 'downloadrace.php?raceID=6&json=1', '')
# (7, 'Green Mountain Stage Race Stage 2', datetime.datetime(2008, 8, 31, 0, 0), '', 'downloadrace.php?raceID=7&json=1', '')
# (8, 'Green Mountain Stage Race Stage 1', datetime.datetime(2008, 8, 30, 0, 0), '', 'downloadrace.php?raceID=8&json=1', '')
# (9, 'Green Mountain Stage Race Prologue', datetime.datetime(2008, 8, 29, 0, 0), '', 'downloadrace.php?raceID=9&json=1', '')
# (10, 'Saco Bay Criterium', datetime.datetime(2008, 8, 23, 0, 0), '', 'downloadrace.php?raceID=10&json=1', '')
# (11, 'Blount Seafoods Fall River Criterium', datetime.datetime(2008, 8, 17, 0, 0), '', 'downloadrace.php?raceID=11&json=1', '')

# %% [markdown]
# # Race results

# %%
index=1000
json = dill.load(open(f'C:\\data\\results\\races\\{index}.pkd', 'rb'))

df_race = pd.read_json(json)
df_race = clean(df_race).dropna(subset=['Place']) # drop DNFs
df_race = df_race.assign(race_id=int(index))
df_race.head()
# Out:
#    Place RaceTime             Name   Age  Category  RacerID  TeamID  \
# 0    1.0                Luke Demoe   NaN       NaN    12069   13113
# 1    2.0                Joe Dengel   NaN       NaN    14499    3257
# 2    3.0             Daniel Penner  25.0       3.0    14953    4627
# 3    4.0                Chris Ward   NaN       NaN    10755    4513
# 4    5.0           Brian Engelhard  36.0       2.0    11409    4647
#
#                     TeamName                             RaceName  \
# 0           SLOCUM Race Team  Swan Island Rose Festival Criterium
# 1                        NaN  Swan Island Rose Festival Criterium
# 2  Ironclad Performance Wear  Swan Island Rose Festival Criterium
# 3      Guinness Cycling Team  Swan Island Rose Festival Criterium
# 4        bicycleattorney.com  Swan Island Rose Festival Criterium
#
#   RaceCategoryName   IsDQ  race_id
# 0       Category 3  False     1000
# 1       Category 3  False     1000
# 2       Category 3  False     1000
# 3       Category 3  False     1000
# 4       Category 3  False     1000

# %%
Base = declarative_base()

class Races(Base):
    __tablename__ = "races"
    
    # sqlalchemy uses these names as the column names
    Index = Column(Integer, primary_key=True)
    Place = Column(Integer)
    Name = Column(String)
    Age = Column(Integer)
    Category = Column(Integer)
    RacerID = Column(Integer)
    TeamID = Column(Integer)
    TeamName = Column(String)
    RaceName = Column(String)
    RaceCategoryName = Column(String)
    race_id = Column(Integer)
    prev_mu = Column(Float)
    prev_sigma = Column(Float)
    mu = Column(Float)
    sigma = Column(Float)

# %%
Races.__table__.drop(engine, checkfirst=True)

# %%
for j, (index, row) in enumerate(df_meta.iterrows()):
    if j == 100:
        break
        
    json = dill.load(open(f'C:\\data\\results\\races\\{index}.pkd', 'rb'))
        
    df_race = pd.read_json(json)
    if df_race.empty:
        continue
        
    df_race = clean(df_race).dropna(subset=['Place']) # drop DNFs
    df_race = df_race.assign(race_id=int(index), prev_mu=None, prev_sigma=None, mu=None, sigma=None)

    cols = ['Place', 'Name', 'Age', 'Category', 'RacerID', 'TeamID', 'TeamName', 'RaceName', 
            'RaceCategoryName', 'race_id', 'prev_mu', 'prev_sigma', 'mu', 'sigma']
    df_race[cols].to_sql('races', engine, if_exists='append')

# %%
results = session.query(Races.Index, Races.Place, Races.Name, Races.Age, Races.Category, Races.RacerID,
                        Races.TeamID, Races.TeamName, Races.RaceName, Races.RaceCategoryName, Races.race_id,
                        Races.prev_mu, Races.prev_sigma, Races.mu, Races.sigma)
for row in results[:5]:
    print(row)
# Out:
# (0, 1.0, 'Matt Cuttler', 29.0, 3.0, 699, 12737.0, 'CRCA/Affinity Cycles', 'NCC 10th Tour of the Hilltowns', 'Cat 4                ', 2, None, None, None, None)
# (1, 2.0, 'Eric Weinrich', 42.0, 3.0, 700, 1249.0, 'portland velo-cycle-mania', 'NCC 10th Tour of the Hilltowns', 'Cat 4                ', 2, None, None, None, None)
# (2, 3.0, 'Michael Boardman', 34.0, 3.0, 701, None, None, 'NCC 10th Tour of the Hilltowns', 'Cat 4                ', 2, None, None, None, None)
# (3, 4.0, 'John Nobile', 45.0, 4.0, 702, None, None, 'NCC 10th Tour of the Hilltowns', 'Cat 4                ', 2, None, None, None, None)
# (4, 5.0, 'Ryan Short', 20.0, 4.0, 703, 1222.0, 'TEAM PLACID PLANET', 'NCC 10th Tour of the Hilltowns', 'Cat 4                ', 2, None, None, None, None)

# %%
results = session.query(Races.Index, Races.Place, Races.Name, Races.RacerID, Races.RaceName, Races.RaceCategoryName, Races.race_id,
                        Races.prev_mu, Races.prev_sigma, Races.mu, Races.sigma)\
                 .group_by(Races.RaceName, Races.RaceCategoryName)
for row in results[:10]:
    print(row)
# Out:
# (0, 1.0, 'Bill Yabroudy', 1693, '2nd Annual CT Coast Criterium', 'Cat 3/4 Men', 43, None, None, None, None)
# (14, 1.0, 'Eric Robertson', 3728, '2nd Annual CT Coast Criterium', 'Cat 4 Men', 43, None, None, None, None)
# (34, 1.0, 'Nathan Etchells', 77, '2nd Annual CT Coast Criterium', 'Cat 5', 43, None, None, None, None)
# (43, 1.0, 'Jeffrey Kozlowski', 717, '2nd Annual CT Coast Criterium', 'Cat 5 35+', 43, None, None, None, None)
# (55, 1.0, 'Benjamin Wolfe', 74, '2nd Annual CT Coast Criterium', 'Junior Men', 43, None, None, None, None)
# (57, 1.0, 'Claudio Mucci', 3651, '2nd Annual CT Coast Criterium', 'Master Men', 43, None, None, None, None)
# (95, 1.0, 'Christopher Thornton', 3376, '2nd Annual CT Coast Criterium', 'Pro/1/2/3 Men', 43, None, None, None, None)
# (0, 1.0, 'Marshall Johnson', 104, '4th Annual Rick Newhouse Memorial Ninigret Criterium', 'Cat 4             ', 86, None, None, None, None)
# (22, 1.0, 'Greg Louro', 5739, '4th Annual Rick Newhouse Memorial Ninigret Criterium', 'Cat 5              ', 86, None, None, None, None)
# (34, 1.0, 'Ian Mcfarland', 82, '4th Annual Rick Newhouse Memorial Ninigret Criterium', 'Juniors 17-18            ', 86, None, None, None, None)

# %% [markdown]
# # Postgres

# %%
import dill
import re
import glob

import pandas as pd
import trueskill as ts
import numpy as np
import matplotlib.pyplot as plt

ts.setup(backend='mpmath')
RATING = {'mu': ts.MU, 'sigma': ts.SIGMA}  # initial rating

import sys
sys.path.insert(0, '..')
from preprocess import clean

# %%
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, DateTime, Float


engine = sqlalchemy.create_engine('sqlite:///data/races.sqlite')
session = sqlalchemy.orm.sessionmaker(bind=engine)()

# %%
df_meta = pd.read_pickle('C:/data/results/df.pkl')
df_meta.head(5)
# Out:
#                                                       name  \
# race_id
# 2                           NCC 10th Tour of the Hilltowns
# 3                   Bethel Spring Series - Ronde de Bethel
# 4        4th Annual Smuttynose Brewing Co. Portsmouth C...
# 5                                   Topsfield Circuit Race
# 6                                Green Mountain Stage Crit
#
#                         date loc                          json_url weather  \
# race_id
# 2        2008-07-26 00:00:00      downloadrace.php?raceID=2&json=1
# 3        2008-03-02 00:00:00      downloadrace.php?raceID=3&json=1
# 4        2008-09-21 00:00:00      downloadrace.php?raceID=4&json=1
# 5        2008-09-06 00:00:00      downloadrace.php?raceID=5&json=1
# 6        2008-09-01 00:00:00      downloadrace.php?raceID=6&json=1
#
#                               strava_url coord
# race_id
# 2        http://app.strava.com/segments/  None
# 3        http://app.strava.com/segments/  None
# 4        http://app.strava.com/segments/  None
# 5        http://app.strava.com/segments/  None
# 6        http://app.strava.com/segments/  None

# %%
def get_lat_lng(x):
    if x['coord']:
        x['lat'] = float(x['coord'][0])
        x['lng'] = float(x['coord'][1])
    return x
    
df_meta = df_meta.apply(get_lat_lng, axis=1)

# %%
df_meta
# Out:
#                                          coord       date  \
# race_id
# 2                                         None 2008-07-26
# 3                                         None 2008-03-02
# 4                                         None 2008-09-21
# 5                                         None 2008-09-06
# 6                                         None 2008-09-01
# ...                                        ...        ...
# 12604    (40.4854888916016, -106.833557128906) 2020-09-06
# 12605    (40.4854888916016, -106.833557128906) 2020-09-06
# 12606    (40.7584762573242, -111.888145446777) 2020-09-26
# 12607    (41.0463790893555, -95.7417907714844) 2020-09-19
# 12608    (41.0463790893555, -95.7417907714844) 2020-09-19
#
#                                      json_url        lat         lng  \
# race_id
# 2            downloadrace.php?raceID=2&json=1        NaN         NaN
# 3            downloadrace.php?raceID=3&json=1        NaN         NaN
# 4            downloadrace.php?raceID=4&json=1        NaN         NaN
# 5            downloadrace.php?raceID=5&json=1        NaN         NaN
# 6            downloadrace.php?raceID=6&json=1        NaN         NaN
# ...                                       ...        ...         ...
# 12604    downloadrace.php?raceID=12604&json=1  40.485489 -106.833557
# 12605    downloadrace.php?raceID=12605&json=1  40.485489 -106.833557
# 12606    downloadrace.php?raceID=12606&json=1  40.758476 -111.888145
# 12607    downloadrace.php?raceID=12607&json=1  41.046379  -95.741791
# 12608    downloadrace.php?raceID=12608&json=1  41.046379  -95.741791
#
#                            loc  \
# race_id
# 2
# 3
# 4
# 5
# 6
# ...                        ...
# 12604    Steamboat Springs, CO
# 12605    Steamboat Springs, CO
# 12606       Salt Lake City, UT
# 12607             Glenwood, IA
# 12608             Glenwood, IA
#
#                                                       name  \
# race_id
# 2                           NCC 10th Tour of the Hilltowns
# 3                   Bethel Spring Series - Ronde de Bethel
# 4        4th Annual Smuttynose Brewing Co. Portsmouth C...
# 5                                   Topsfield Circuit Race
# 6                                Green Mountain Stage Crit
# ...                                                    ...
# 12604                         Steamboat Springs Stage Race
# 12605                         Steamboat Springs Stage Race
# 12606                                East Canyon Road Race
# 12607                         2020 Glenwood Gravel Grinder
# 12608                         2020 Glenwood Gravel Grinder
#
#                               strava_url                          weather
# race_id
# 2        http://app.strava.com/segments/
# 3        http://app.strava.com/segments/
# 4        http://app.strava.com/segments/
# 5        http://app.strava.com/segments/
# 6        http://app.strava.com/segments/
# ...                                  ...                              ...
# 12604    http://app.strava.com/segments/   Clear, 81  degrees, wind 5 mph
# 12605    http://app.strava.com/segments/   Clear, 81  degrees, wind 5 mph
# 12606    http://app.strava.com/segments/   Clear, 71  degrees, wind 7 mph
# 12607    http://app.strava.com/segments/  Clear, 67  degrees, wind 17 mph
# 12608    http://app.strava.com/segments/  Clear, 67  degrees, wind 17 mph
#
# [12132 rows x 9 columns]

# %%
from flask_sqlalchemy import SQLAlchemy
db = SQLAlchemy()

# %%
db.Float
# Out:
# sqlalchemy.sql.schema.Column

# %%
df_meta.reset_index()
# Out:
#        race_id                                  coord       date  \
# 0            2                                   None 2008-07-26
# 1            3                                   None 2008-03-02
# 2            4                                   None 2008-09-21
# 3            5                                   None 2008-09-06
# 4            6                                   None 2008-09-01
# ...        ...                                    ...        ...
# 12127    12604  (40.4854888916016, -106.833557128906) 2020-09-06
# 12128    12605  (40.4854888916016, -106.833557128906) 2020-09-06
# 12129    12606  (40.7584762573242, -111.888145446777) 2020-09-26
# 12130    12607  (41.0463790893555, -95.7417907714844) 2020-09-19
# 12131    12608  (41.0463790893555, -95.7417907714844) 2020-09-19
#
#                                    json_url        lat         lng  \
# 0          downloadrace.php?raceID=2&json=1        NaN         NaN
# 1          downloadrace.php?raceID=3&json=1        NaN         NaN
# 2          downloadrace.php?raceID=4&json=1        NaN         NaN
# 3          downloadrace.php?raceID=5&json=1        NaN         NaN
# 4          downloadrace.php?raceID=6&json=1        NaN         NaN
# ...                                     ...        ...         ...
# 12127  downloadrace.php?raceID=12604&json=1  40.485489 -106.833557
# 12128  downloadrace.php?raceID=12605&json=1  40.485489 -106.833557
# 12129  downloadrace.php?raceID=12606&json=1  40.758476 -111.888145
# 12130  downloadrace.php?raceID=12607&json=1  41.046379  -95.741791
# 12131  downloadrace.php?raceID=12608&json=1  41.046379  -95.741791
#
#                          loc  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...
# 12127  Steamboat Springs, CO
# 12128  Steamboat Springs, CO
# 12129     Salt Lake City, UT
# 12130           Glenwood, IA
# 12131           Glenwood, IA
#
#                                                     name  \
# 0                         NCC 10th Tour of the Hilltowns
# 1                 Bethel Spring Series - Ronde de Bethel
# 2      4th Annual Smuttynose Brewing Co. Portsmouth C...
# 3                                 Topsfield Circuit Race
# 4                              Green Mountain Stage Crit
# ...                                                  ...
# 12127                       Steamboat Springs Stage Race
# 12128                       Steamboat Springs Stage Race
# 12129                              East Canyon Road Race
# 12130                       2020 Glenwood Gravel Grinder
# 12131                       2020 Glenwood Gravel Grinder
#
#                             strava_url                          weather
# 0      http://app.strava.com/segments/
# 1      http://app.strava.com/segments/
# 2      http://app.strava.com/segments/
# 3      http://app.strava.com/segments/
# 4      http://app.strava.com/segments/
# ...                                ...                              ...
# 12127  http://app.strava.com/segments/   Clear, 81  degrees, wind 5 mph
# 12128  http://app.strava.com/segments/   Clear, 81  degrees, wind 5 mph
# 12129  http://app.strava.com/segments/   Clear, 71  degrees, wind 7 mph
# 12130  http://app.strava.com/segments/  Clear, 67  degrees, wind 17 mph
# 12131  http://app.strava.com/segments/  Clear, 67  degrees, wind 17 mph
#
# [12132 rows x 10 columns]
